# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
from getdist import *

# import planckStyle
import pylab
import numpy as np
import matplotlib
import tkinter

matplotlib.use('TkAgg')


# %matplotlib inline

# %%
dir_name = '/home/cosmocicatais/simpleMC/chains_test/'
roots = ['owaCDM_phy_HD+SN+BBAO+Planck_nested_dynesty_multi',
         'owaCDM_phy_HD+SN+BBAO+Planck_neuralike_nested_dynesty_multi']

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# %%
g.settings.lab_fontsize = 20
g.settings.x_label_rotation= 45
g.settings.legend_fontsize = 20
g.settings.axes_fontsize = 20

g.triangle_plot(roots, ['Om', 'Obh2', 'h', 'w', 'wa', 'Ok'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['red','blue'], 
                               'alphas':[1.0,1.0]},
                colors=['red','blue'],
                legend_labels=['Ordinary likelihoods evaluations: 12:57 min',
                               'Neural likelihoods evaluations: 8.86 min'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('Comparison_test1.png', dpi=100)
