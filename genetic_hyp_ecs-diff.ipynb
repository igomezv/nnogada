# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import time, os
import random
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, LeakyReLU
from tensorflow.keras.utils import to_categorical
from tensorboard.plugins.hparams import api as hp

from tensorflow.keras import activations
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model

import random
from math import floor
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from scipy.integrate import odeint

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split as split
from scipy.stats import bernoulli

# import deap
from deap import base, creator, tools, algorithms

from bitstring import BitArray

from elitism import eaSimpleWithElitism, main
# Out:
# Elitism succesfully imported

# %%
np.random.seed(0)

# tf.config.optimizer.set_jit(True)
scaler = StandardScaler()

# %%
#algorithm for splitting the dataset into training and validation 
def split(X,Y,porcent): #porcent must be between 0 and 1, it is the asigned porcent to the training dataset.
    n=floor(porcent*len(X))
    index=random.sample(range(len(X)),n)
    X_learn=[]
    Y_learn=[]
    for i in index:
        X_learn.append(X[i])
        Y_learn.append(Y[i])
    X_val=np.delete(X,index, axis=0)
    Y_val=np.delete(Y,index, axis=0)
    
    X_learn=np.array(X_learn)
    Y_learn=np.array(Y_learn)
    return X_learn,Y_learn,X_val,Y_val

# %%
O_m=np.arange(0.1,0.51,0.1)
H_0=np.arange(66,81,1)
t=np.linspace(0,-12,50)

# %%
def RHS(Omega_i, lna, gamma=0):
    x, y, z, H = Omega_i
    #x, y, z = Omega_i
    pi = 3*x + 4*y
    return [x*(-3 + pi), y*(-4 + pi), z*pi, -0.5*H*pi]
    #return [x*(-3 + pi), y*(-4 + pi), z*pi]

def EDO(t,Om,H0):
    #t,Or,Om,Ol=X
    Or=0.0001
    Ol=1-Or-Om
    #H0 = 70.
    y0 = [Om, Or, Ol, H0]
    result = odeint(RHS, y0, t)
    return result

# %%
#lets generate the cartesian product between the intervals
Y0=[]
#este ciclo llena la lista fijando un Om y pasando todos los Or
for i in O_m:
    for j in H_0:
        Y0.extend(EDO(t,i,j))
Y0=np.array(Y0)

X0=[]
for Om in O_m:
    for H0 in H_0:
        for T in t:
            X0.append([T,Om,H0])
X0=np.array(X0)

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler(feature_range = (0,1))
Y2 = scaler.fit_transform(Y0)

# %%
#Now, here are the datasets
print('feactures= \n',X0)
print('\n')
print('labels= \n',Y2)
# Out:
# feactures=
#  [[  0.           0.1         66.        ]
#  [ -0.24489796   0.1         66.        ]
#  [ -0.48979592   0.1         66.        ]
#  ...
#  [-11.51020408   0.5         80.        ]
#  [-11.75510204   0.5         80.        ]
#  [-12.           0.5         80.        ]]
#
#
# labels=
#  [[9.47515373e-02 0.00000000e+00 1.00000000e+00 0.00000000e+00]
#  [1.83608702e-01 1.41110961e-04 9.01997379e-01 1.62358493e-10]
#  [3.22333902e-01 4.33937896e-04 7.48914062e-01 4.77144941e-10]
#  ...
#  [4.20164900e-02 9.58104047e-01 5.58400899e-11 3.78984027e-01]
#  [3.19464665e-02 9.68145182e-01 5.73926010e-11 6.15280156e-01]
#  [2.39153274e-02 9.76153281e-01 5.75107557e-11 1.00000000e+00]]

# %%
split_size = 0.8
X_train, Y_train, X_test, Y_test = split(X0, Y2, split_size)

# %%
SC_DEEP       = np.array([3,4])                           # Number of deep layers (8)
SC_NUM_UNITS  = np.array([50,100,200]) # Number of fully conected neurons (16)
SC_LEARNING   = np.array([1e-5,1e-4,1e-3])   # Learning rates (8)
SC_BATCH      = np.array([4, 8,16])                            # Batch sizes (4)
# SC_ACTIVATION = [f1, f2, f3, f4]                                      # Activation function layers (2)

my_callbacks = [tf.keras.callbacks.EarlyStopping(
                               monitor='val_loss', mode='min',
                               min_delta=0, 
                               patience=100,
                               verbose=1,
                            #    baseline=0,
                               restore_best_weights=1)
#                 keras.callbacks.TensorBoard(
#                                log_dir='./logs'),
#                 keras.callbacks.ReduceLROnPlateau(
#                                monitor='val_loss', factor=0.5,
#                                patience=6, min_lr=0,
#                                verbose=1)
               ] 
    
epochs = 500
# epochs = 3

# %%
# Produces train and val splits.
X_test, Y_test, X_val, Y_val = split(X_test, Y_test, 0.5)

# %%
def train_evaluate(ga_individual_solution):   
    t = time.time()
    t_total = 0
    
    # Decode GA solution to integer for window_size and num_units
    deep_layers_bits   = BitArray(ga_individual_solution[0:1])     # (8)
    num_units_bits     = BitArray(ga_individual_solution[1:2])     # (16)
    learning_rate_bits = BitArray(ga_individual_solution[2:3])    # (8)
    batch_size_bits    = BitArray(ga_individual_solution[3:4])   # (4)
# #     activation_f_bits  = BitArray(ga_individual_solution[12:13])   # (2)   Solo se consideran las 2 primeras
    
    deep_layers   = SC_DEEP[deep_layers_bits.uint]
    num_units     = SC_NUM_UNITS[num_units_bits.uint]
    learning_rate = SC_LEARNING[learning_rate_bits.uint]
    batch_size   = SC_BATCH[batch_size_bits.uint]
#     activation_f  = SC_ACTIVATION[activation_f_bits.uint]

    
    print('\n--------------- Starting trial:', population_size*(max_generations+1)-len(ss), "---------------")
    print('Deep layers:',deep_layers,', Number of neurons:',num_units,", Learning rate:",learning_rate)
#     print("-------------------------------------------------")
    
    # Train model and predict on validation set
    model = tf.keras.Sequential()
    model.add(Dense(int(X_train.shape[1])))
    
    for i in range(deep_layers):        
        model.add(Dense(num_units, activation='relu'))
#             model.add(keras.layers.Dropout(0.3))
    model.add(Dense(4, activation='linear'))
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-3)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mean_squared_error'])
    model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_val, Y_val),
              callbacks=my_callbacks, batch_size=batch_size, shuffle=False, verbose=0)
    
    loss, score = model.evaluate(X_val, Y_val)    
    t = time.time()-t
    ss.pop(0)
    print("Loss:", score, ", Elapsed time:", t)
    print("-------------------------------------------------\n")
#     print(loss, score)

    datos.append([deep_layers, num_units, learning_rate, batch_size, loss, score, t])
    
    return loss,

# %%
X_train.shape, X_test.shape, X_val.shape
# Out:
# ((3000, 3), (375, 3), (375, 3))

# %%
from deap import tools
from deap import algorithms

def eaSimpleWithElitism(population, toolbox, cxpb, mutpb, ngen, stats=None,
             halloffame=None, verbose=__debug__):
    """This algorithm is similar to DEAP eaSimple() algorithm, with the modification that
    halloffame is used to implement an elitism mechanism. The individuals contained in the
    halloffame are directly injected into the next generation and are not subject to the
    genetic operators of selection, crossover and mutation.
    """
    logbook = tools.Logbook()
    logbook.header = ['gen', 'nevals'] + (stats.fields if stats else [])

    # Evaluate the individuals with an invalid fitness
    invalid_ind = [ind for ind in population if not ind.fitness.valid]
    fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    if halloffame is None:
        raise ValueError("halloffame parameter must not be empty!")

    halloffame.update(population)
    hof_size = len(halloffame.items) if halloffame.items else 0

    record = stats.compile(population) if stats else {}
    logbook.record(gen=0, nevals=len(invalid_ind), **record)
    if verbose:
        print(logbook.stream)

    # Begin the generational process
    for gen in range(1, ngen + 1):

        # Select the next generation individuals
        offspring = toolbox.select(population, len(population) - hof_size)

        # Vary the pool of individuals
        offspring = algorithms.varAnd(offspring, toolbox, cxpb, mutpb)

        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        # add the best back to population:
        offspring.extend(halloffame.items)

        # Update the hall of fame with the generated individuals
        halloffame.update(offspring)

        # Replace the current population by the offspring
        population[:] = offspring

        # Append the current generation statistics to the logbook
        record = stats.compile(population) if stats else {}
        logbook.record(gen=gen, nevals=len(invalid_ind), **record)
        if verbose:
            print(logbook.stream)

    return population, logbook

# %%
def geneticAlgorithm_with_elitism(population_size, max_generations, gene_length, k):
    
    # Genetic Algorithm constants:
    P_CROSSOVER = 0.8        # probability for crossover
    P_MUTATION = 0.2         # probability for mutating an individual
    HALL_OF_FAME_SIZE = 1    # Best individuals that pass to the other generation
    
    # set the random seed:
    toolbox = base.Toolbox()

    # As we are trying to minimize the RMSE score, that's why using -1.0. 
    # In case, when you want to maximize accuracy for instance, use 1.0
    creator.create('FitnessMin', base.Fitness, weights = [-1.0])
    creator.create('Individual', list , fitness = creator.FitnessMin)

    # create the individual operator to fill up an Individual instance:
    toolbox.register('binary', bernoulli.rvs, 0.5)
    toolbox.register('individual', tools.initRepeat, creator.Individual, toolbox.binary, n = gene_length)

    # create the population operator to generate a list of individuals:
    toolbox.register('population', tools.initRepeat, list , toolbox.individual)

    # genetic operators:
    toolbox.register('evaluate', train_evaluate)
    toolbox.register('select', tools.selTournament, tournsize = 2)
    toolbox.register('mutate', tools.mutFlipBit, indpb = 0.11)
    toolbox.register('mate', tools.cxUniform, indpb = 0.5)
    
    # create initial population (generation 0):
    population = toolbox.population(n=population_size)

    # prepare the statistics object:
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("min", np.min)
    stats.register("avg", np.mean)
    stats.register("max", np.max)

    # define the hall-of-fame object:
    hof = tools.HallOfFame(HALL_OF_FAME_SIZE)

    # Genetic Algorithm flow with elitism:
    population, logbook = eaSimpleWithElitism(population, toolbox, cxpb=P_CROSSOVER, mutpb=P_MUTATION,
                                              ngen=max_generations, stats=stats, halloffame=hof, verbose=True)

    # print info for best solution found:
    best = hof.items[0]
    print("-- Best Individual = ", best)
    print("-- Best Fitness = ", best.fitness.values[0])

    # extract statistics:
    minFitnessValues, meanFitnessValues, maxFitnessValues = logbook.select("min", "max", "avg")

    # plot statistics:
    sns.set_style("whitegrid")
    plt.plot(minFitnessValues, color='blue', label="Min")
    plt.plot(meanFitnessValues, color='green', label="Mean")
    plt.plot(maxFitnessValues, color='red', label="Max")
    plt.xlabel('Generation'); plt.ylabel('Max / Min / Average Fitness')
    plt.legend()
    plt.title('Max, Min and Average fitness over Generations')
    plt.show()
    
    best_population = tools.selBest(population,k = k)
    return best_population

# %%
population_size = 20   # max of individuals per generation
max_generations = 5    # number of generations
gene_length = 4       # lenght of the gene, depends on how many hiperparameters are tested  
k = 1;                 # num. of finalist individuals

if __name__ == "__main__":
    t = time.time(); 
    datos = [];
    ss = [i for i in range(1,population_size*(max_generations+1))]
    best_population = geneticAlgorithm_with_elitism(population_size, max_generations, gene_length, k)
    print("Total elapsed time:", (time.time()-t)/60, "minutes")
# Out:
# --------------- Starting trial: 1 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 772us/step - loss: 8.3534e-04 - mean_squared_error: 8.3534e-04
# Loss: 0.0008353447774425149 , Elapsed time: 143.2963719367981
# -------------------------------------------------
#
#
# --------------- Starting trial: 2 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 780us/step - loss: 0.0040 - mean_squared_error: 0.0040
# Loss: 0.003975101746618748 , Elapsed time: 157.35589337348938
# -------------------------------------------------
#
#
# --------------- Starting trial: 3 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# Restoring model weights from the end of the best epoch: 368.
# Epoch 468: early stopping
# 12/12 [==============================] - 0s 674us/step - loss: 6.2087e-04 - mean_squared_error: 6.2087e-04
# Loss: 0.0006208726554177701 , Elapsed time: 141.53257393836975
# -------------------------------------------------
#
#
# --------------- Starting trial: 4 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 689us/step - loss: 0.0037 - mean_squared_error: 0.0037
# Loss: 0.003661157563328743 , Elapsed time: 299.55448818206787
# -------------------------------------------------
#
#
# --------------- Starting trial: 5 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 709us/step - loss: 3.8963e-04 - mean_squared_error: 3.8963e-04
# Loss: 0.0003896295966114849 , Elapsed time: 142.3026442527771
# -------------------------------------------------
#
#
# --------------- Starting trial: 6 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 838us/step - loss: 0.0046 - mean_squared_error: 0.0046
# Loss: 0.0046229069121181965 , Elapsed time: 146.27196645736694
# -------------------------------------------------
#
#
# --------------- Starting trial: 7 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 699us/step - loss: 0.0063 - mean_squared_error: 0.0063
# Loss: 0.006251930724829435 , Elapsed time: 139.46258234977722
# -------------------------------------------------
#
#
# --------------- Starting trial: 8 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 739us/step - loss: 0.0057 - mean_squared_error: 0.0057
# Loss: 0.005675200372934341 , Elapsed time: 150.61875367164612
# -------------------------------------------------
#
#
# --------------- Starting trial: 9 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 693us/step - loss: 0.0045 - mean_squared_error: 0.0045
# Loss: 0.00453924061730504 , Elapsed time: 151.42670440673828
# -------------------------------------------------
#
#
# --------------- Starting trial: 10 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 732us/step - loss: 8.3428e-04 - mean_squared_error: 8.3428e-04
# Loss: 0.0008342768414877355 , Elapsed time: 160.74338912963867
# -------------------------------------------------
#
#
# --------------- Starting trial: 11 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 711us/step - loss: 4.4554e-04 - mean_squared_error: 4.4554e-04
# Loss: 0.00044553805491887033 , Elapsed time: 283.6298997402191
# -------------------------------------------------
#
#
# --------------- Starting trial: 12 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 807us/step - loss: 0.0061 - mean_squared_error: 0.0061
# Loss: 0.006089183036237955 , Elapsed time: 306.55963611602783
# -------------------------------------------------
#
#
# --------------- Starting trial: 13 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 783us/step - loss: 9.5485e-04 - mean_squared_error: 9.5485e-04
# Loss: 0.0009548459784127772 , Elapsed time: 282.8747773170471
# -------------------------------------------------
#
#
# --------------- Starting trial: 14 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 754us/step - loss: 0.0049 - mean_squared_error: 0.0049
# Loss: 0.004899137653410435 , Elapsed time: 290.5013484954834
# -------------------------------------------------
#
#
# --------------- Starting trial: 15 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 784us/step - loss: 0.0020 - mean_squared_error: 0.0020
# Loss: 0.0019724294543266296 , Elapsed time: 292.97752499580383
# -------------------------------------------------
#
#
# --------------- Starting trial: 16 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 681us/step - loss: 3.2602e-04 - mean_squared_error: 3.2602e-04
# Loss: 0.0003260234370827675 , Elapsed time: 285.51339387893677
# -------------------------------------------------
#
#
# --------------- Starting trial: 17 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 687us/step - loss: 6.2758e-04 - mean_squared_error: 6.2758e-04
# Loss: 0.0006275774794630706 , Elapsed time: 284.1924796104431
# -------------------------------------------------
#
#
# --------------- Starting trial: 18 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 760us/step - loss: 1.7338e-04 - mean_squared_error: 1.7338e-04
# Loss: 0.0001733780518407002 , Elapsed time: 291.2258245944977
# -------------------------------------------------
#
#
# --------------- Starting trial: 19 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 715us/step - loss: 6.2410e-05 - mean_squared_error: 6.2410e-05
# Loss: 6.24097156105563e-05 , Elapsed time: 307.09251832962036
# -------------------------------------------------
#
#
# --------------- Starting trial: 20 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 812us/step - loss: 0.0040 - mean_squared_error: 0.0040
# Loss: 0.004008343443274498 , Elapsed time: 284.0916111469269
# -------------------------------------------------
#
# gen	nevals	min        	avg       	max
# 0  	20    	6.24097e-05	0.00254823	0.00625193
#
# --------------- Starting trial: 21 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 719us/step - loss: 5.5156e-04 - mean_squared_error: 5.5156e-04
# Loss: 0.0005515622906386852 , Elapsed time: 285.67134284973145
# -------------------------------------------------
#
#
# --------------- Starting trial: 22 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 657us/step - loss: 4.7592e-04 - mean_squared_error: 4.7592e-04
# Loss: 0.0004759244911838323 , Elapsed time: 284.4982018470764
# -------------------------------------------------
#
#
# --------------- Starting trial: 23 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 644us/step - loss: 0.0074 - mean_squared_error: 0.0074
# Loss: 0.0074330540373921394 , Elapsed time: 152.8016698360443
# -------------------------------------------------
#
#
# --------------- Starting trial: 24 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 797us/step - loss: 1.9711e-04 - mean_squared_error: 1.9711e-04
# Loss: 0.00019711273489519954 , Elapsed time: 288.52770495414734
# -------------------------------------------------
#
#
# --------------- Starting trial: 25 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 793us/step - loss: 0.0032 - mean_squared_error: 0.0032
# Loss: 0.003195174504071474 , Elapsed time: 154.67907977104187
# -------------------------------------------------
#
#
# --------------- Starting trial: 26 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 854us/step - loss: 3.6307e-05 - mean_squared_error: 3.6307e-05
# Loss: 3.630670107668266e-05 , Elapsed time: 312.67593121528625
# -------------------------------------------------
#
#
# --------------- Starting trial: 27 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 730us/step - loss: 8.5409e-05 - mean_squared_error: 8.5409e-05
# Loss: 8.540891576558352e-05 , Elapsed time: 306.56942486763
# -------------------------------------------------
#
#
# --------------- Starting trial: 28 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 778us/step - loss: 0.0034 - mean_squared_error: 0.0034
# Loss: 0.0034410629887133837 , Elapsed time: 292.92746901512146
# -------------------------------------------------
#
#
# --------------- Starting trial: 29 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 737us/step - loss: 1.1059e-04 - mean_squared_error: 1.1059e-04
# Loss: 0.00011058556265197694 , Elapsed time: 283.37508821487427
# -------------------------------------------------
#
#
# --------------- Starting trial: 30 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 735us/step - loss: 1.7285e-04 - mean_squared_error: 1.7285e-04
# Loss: 0.00017285211652051657 , Elapsed time: 292.60687732696533
# -------------------------------------------------
#
#
# --------------- Starting trial: 31 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 719us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Loss: 0.0012568669626489282 , Elapsed time: 157.35136151313782
# -------------------------------------------------
#
#
# --------------- Starting trial: 32 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 624us/step - loss: 2.0810e-04 - mean_squared_error: 2.0810e-04
# Loss: 0.00020809956185985357 , Elapsed time: 281.4249064922333
# -------------------------------------------------
#
#
# --------------- Starting trial: 33 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 610us/step - loss: 2.7169e-04 - mean_squared_error: 2.7169e-04
# Loss: 0.00027168853557668626 , Elapsed time: 281.1206066608429
# -------------------------------------------------
#
#
# --------------- Starting trial: 34 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 643us/step - loss: 0.0039 - mean_squared_error: 0.0039
# Loss: 0.0038692038506269455 , Elapsed time: 281.14326000213623
# -------------------------------------------------
#
#
# --------------- Starting trial: 35 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 721us/step - loss: 9.5679e-04 - mean_squared_error: 9.5679e-04
# Loss: 0.0009567946544848382 , Elapsed time: 145.25301814079285
# -------------------------------------------------
#
#
# --------------- Starting trial: 36 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 740us/step - loss: 0.0031 - mean_squared_error: 0.0031
# Loss: 0.0031235385686159134 , Elapsed time: 278.460857629776
# -------------------------------------------------
#
#
# --------------- Starting trial: 37 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 691us/step - loss: 2.5998e-04 - mean_squared_error: 2.5998e-04
# Loss: 0.0002599812869448215 , Elapsed time: 268.52033853530884
# -------------------------------------------------
#
#
# --------------- Starting trial: 38 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# Restoring model weights from the end of the best epoch: 357.
# Epoch 457: early stopping
# 12/12 [==============================] - 0s 747us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Loss: 0.0010026380186900496 , Elapsed time: 133.46927857398987
# -------------------------------------------------
#
# 1  	18    	3.63067e-05	0.00153427	0.00743305
#
# --------------- Starting trial: 39 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 678us/step - loss: 1.4517e-04 - mean_squared_error: 1.4517e-04
# Loss: 0.00014517447561956942 , Elapsed time: 282.6061487197876
# -------------------------------------------------
#
#
# --------------- Starting trial: 40 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 697us/step - loss: 0.0031 - mean_squared_error: 0.0031
# Loss: 0.003130991943180561 , Elapsed time: 266.58525347709656
# -------------------------------------------------
#
#
# --------------- Starting trial: 41 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# Restoring model weights from the end of the best epoch: 298.
# Epoch 398: early stopping
# 12/12 [==============================] - 0s 698us/step - loss: 5.3092e-04 - mean_squared_error: 5.3092e-04
# Loss: 0.0005309246480464935 , Elapsed time: 116.81643176078796
# -------------------------------------------------
#
#
# --------------- Starting trial: 42 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 714us/step - loss: 0.0024 - mean_squared_error: 0.0024
# Loss: 0.0023608349729329348 , Elapsed time: 267.8132121562958
# -------------------------------------------------
#
#
# --------------- Starting trial: 43 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 687us/step - loss: 3.3524e-04 - mean_squared_error: 3.3524e-04
# Loss: 0.0003352435305714607 , Elapsed time: 281.3792667388916
# -------------------------------------------------
#
#
# --------------- Starting trial: 44 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 710us/step - loss: 3.1997e-04 - mean_squared_error: 3.1997e-04
# Loss: 0.00031996757024899125 , Elapsed time: 297.1409206390381
# -------------------------------------------------
#
#
# --------------- Starting trial: 45 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 726us/step - loss: 1.7347e-04 - mean_squared_error: 1.7347e-04
# Loss: 0.0001734653051244095 , Elapsed time: 145.86120676994324
# -------------------------------------------------
#
#
# --------------- Starting trial: 46 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 696us/step - loss: 2.3151e-04 - mean_squared_error: 2.3151e-04
# Loss: 0.00023150602646637708 , Elapsed time: 284.45398211479187
# -------------------------------------------------
#
#
# --------------- Starting trial: 47 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 640us/step - loss: 3.2507e-04 - mean_squared_error: 3.2507e-04
# Loss: 0.0003250653389841318 , Elapsed time: 297.9670977592468
# -------------------------------------------------
#
#
# --------------- Starting trial: 48 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 712us/step - loss: 7.9788e-05 - mean_squared_error: 7.9788e-05
# Loss: 7.978830399224535e-05 , Elapsed time: 279.1110908985138
# -------------------------------------------------
#
#
# --------------- Starting trial: 49 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 719us/step - loss: 1.3928e-04 - mean_squared_error: 1.3928e-04
# Loss: 0.0001392803096678108 , Elapsed time: 281.4175612926483
# -------------------------------------------------
#
#
# --------------- Starting trial: 50 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 686us/step - loss: 0.0049 - mean_squared_error: 0.0049
# Loss: 0.004876244813203812 , Elapsed time: 296.776230096817
# -------------------------------------------------
#
#
# --------------- Starting trial: 51 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 693us/step - loss: 6.3585e-05 - mean_squared_error: 6.3585e-05
# Loss: 6.358462269417942e-05 , Elapsed time: 278.5185821056366
# -------------------------------------------------
#
#
# --------------- Starting trial: 52 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 729us/step - loss: 0.0047 - mean_squared_error: 0.0047
# Loss: 0.004662842955440283 , Elapsed time: 279.9560492038727
# -------------------------------------------------
#
#
# --------------- Starting trial: 53 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 612us/step - loss: 2.3340e-04 - mean_squared_error: 2.3340e-04
# Loss: 0.00023339981271419674 , Elapsed time: 280.7403495311737
# -------------------------------------------------
#
#
# --------------- Starting trial: 54 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 701us/step - loss: 1.7381e-04 - mean_squared_error: 1.7381e-04
# Loss: 0.00017381197540089488 , Elapsed time: 285.0094153881073
# -------------------------------------------------
#
# 2  	16    	6.24097e-05	0.000913876	0.00487624
#
# --------------- Starting trial: 55 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 695us/step - loss: 5.0864e-04 - mean_squared_error: 5.0864e-04
# Loss: 0.0005086429882794619 , Elapsed time: 145.64410424232483
# -------------------------------------------------
#
#
# --------------- Starting trial: 56 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 711us/step - loss: 5.9081e-05 - mean_squared_error: 5.9081e-05
# Loss: 5.908118691877462e-05 , Elapsed time: 280.69638872146606
# -------------------------------------------------
#
#
# --------------- Starting trial: 57 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 692us/step - loss: 3.6717e-04 - mean_squared_error: 3.6717e-04
# Loss: 0.0003671707818284631 , Elapsed time: 296.66636657714844
# -------------------------------------------------
#
#
# --------------- Starting trial: 58 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 645us/step - loss: 1.7684e-04 - mean_squared_error: 1.7684e-04
# Loss: 0.00017683613987173885 , Elapsed time: 281.8949873447418
# -------------------------------------------------
#
#
# --------------- Starting trial: 59 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 710us/step - loss: 1.8545e-04 - mean_squared_error: 1.8545e-04
# Loss: 0.00018545093189459294 , Elapsed time: 283.36916875839233
# -------------------------------------------------
#
#
# --------------- Starting trial: 60 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 729us/step - loss: 4.1062e-05 - mean_squared_error: 4.1062e-05
# Loss: 4.106219785171561e-05 , Elapsed time: 278.68078804016113
# -------------------------------------------------
#
#
# --------------- Starting trial: 61 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 705us/step - loss: 2.3374e-04 - mean_squared_error: 2.3374e-04
# Loss: 0.00023374006559606642 , Elapsed time: 269.24487352371216
# -------------------------------------------------
#
#
# --------------- Starting trial: 62 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 726us/step - loss: 2.5629e-05 - mean_squared_error: 2.5629e-05
# Loss: 2.5628534785937518e-05 , Elapsed time: 279.34069871902466
# -------------------------------------------------
#
#
# --------------- Starting trial: 63 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 646us/step - loss: 1.1608e-04 - mean_squared_error: 1.1608e-04
# Loss: 0.0001160801766673103 , Elapsed time: 282.268013715744
# -------------------------------------------------
#
#
# --------------- Starting trial: 64 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 745us/step - loss: 7.8886e-05 - mean_squared_error: 7.8886e-05
# Loss: 7.888590334914625e-05 , Elapsed time: 279.2551169395447
# -------------------------------------------------
#
#
# --------------- Starting trial: 65 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 722us/step - loss: 2.0826e-04 - mean_squared_error: 2.0826e-04
# Loss: 0.00020826379477512091 , Elapsed time: 281.705961227417
# -------------------------------------------------
#
#
# --------------- Starting trial: 66 ---------------
# Deep layers: 3 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 702us/step - loss: 8.4202e-04 - mean_squared_error: 8.4202e-04
# Loss: 0.0008420213707722723 , Elapsed time: 296.8022413253784
# -------------------------------------------------
#
#
# --------------- Starting trial: 67 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 681us/step - loss: 0.0027 - mean_squared_error: 0.0027
# Loss: 0.002721172058954835 , Elapsed time: 267.527131319046
# -------------------------------------------------
#
#
# --------------- Starting trial: 68 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 844us/step - loss: 3.6161e-04 - mean_squared_error: 3.6161e-04
# Loss: 0.00036160883610136807 , Elapsed time: 281.9916501045227
# -------------------------------------------------
#
#
# --------------- Starting trial: 69 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 694us/step - loss: 1.8515e-04 - mean_squared_error: 1.8515e-04
# Loss: 0.0001851464476203546 , Elapsed time: 282.79483008384705
# -------------------------------------------------
#
#
# --------------- Starting trial: 70 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 649us/step - loss: 2.4205e-04 - mean_squared_error: 2.4205e-04
# Loss: 0.00024205169756896794 , Elapsed time: 284.9834430217743
# -------------------------------------------------
#
#
# --------------- Starting trial: 71 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 626us/step - loss: 3.6877e-05 - mean_squared_error: 3.6877e-05
# Loss: 3.687713251565583e-05 , Elapsed time: 279.86327862739563
# -------------------------------------------------
#
#
# --------------- Starting trial: 72 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 714us/step - loss: 6.3157e-05 - mean_squared_error: 6.3157e-05
# Loss: 6.315676728263497e-05 , Elapsed time: 279.3630602359772
# -------------------------------------------------
#
# 3  	18    	2.56285e-05	0.000329754	0.00272117
#
# --------------- Starting trial: 73 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 583us/step - loss: 2.0958e-04 - mean_squared_error: 2.0958e-04
# Loss: 0.00020958378445357084 , Elapsed time: 283.61608242988586
# -------------------------------------------------
#
#
# --------------- Starting trial: 74 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 703us/step - loss: 7.1440e-05 - mean_squared_error: 7.1440e-05
# Loss: 7.144023402361199e-05 , Elapsed time: 278.9656412601471
# -------------------------------------------------
#
#
# --------------- Starting trial: 75 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 829us/step - loss: 2.1460e-04 - mean_squared_error: 2.1460e-04
# Loss: 0.0002145961916539818 , Elapsed time: 281.17595982551575
# -------------------------------------------------
#
#
# --------------- Starting trial: 76 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 707us/step - loss: 9.0782e-05 - mean_squared_error: 9.0782e-05
# Loss: 9.078245057025924e-05 , Elapsed time: 278.88702726364136
# -------------------------------------------------
#
#
# --------------- Starting trial: 77 ---------------
# Deep layers: 3 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 765us/step - loss: 4.9468e-04 - mean_squared_error: 4.9468e-04
# Loss: 0.0004946784465573728 , Elapsed time: 139.9474081993103
# -------------------------------------------------
#
#
# --------------- Starting trial: 78 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 655us/step - loss: 4.6171e-04 - mean_squared_error: 4.6171e-04
# Loss: 0.0004617109661921859 , Elapsed time: 282.94174695014954
# -------------------------------------------------
#
#
# --------------- Starting trial: 79 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 703us/step - loss: 6.0587e-05 - mean_squared_error: 6.0587e-05
# Loss: 6.058669532649219e-05 , Elapsed time: 280.8012275695801
# -------------------------------------------------
#
#
# --------------- Starting trial: 80 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 684us/step - loss: 7.8949e-05 - mean_squared_error: 7.8949e-05
# Loss: 7.89485129644163e-05 , Elapsed time: 281.0216875076294
# -------------------------------------------------
#
#
# --------------- Starting trial: 81 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 684us/step - loss: 3.4916e-05 - mean_squared_error: 3.4916e-05
# Loss: 3.4915512514999136e-05 , Elapsed time: 280.99575185775757
# -------------------------------------------------
#
#
# --------------- Starting trial: 82 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 1e-05
# 12/12 [==============================] - 0s 636us/step - loss: 0.0036 - mean_squared_error: 0.0036
# Loss: 0.003600344294682145 , Elapsed time: 278.94309306144714
# -------------------------------------------------
#
#
# --------------- Starting trial: 83 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 719us/step - loss: 4.4086e-05 - mean_squared_error: 4.4086e-05
# Loss: 4.408567110658623e-05 , Elapsed time: 279.50514793395996
# -------------------------------------------------
#
#
# --------------- Starting trial: 84 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 706us/step - loss: 1.2528e-04 - mean_squared_error: 1.2528e-04
# Loss: 0.00012528010120149702 , Elapsed time: 281.8970501422882
# -------------------------------------------------
#
#
# --------------- Starting trial: 85 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 713us/step - loss: 1.3414e-04 - mean_squared_error: 1.3414e-04
# Loss: 0.0001341437455266714 , Elapsed time: 280.29612827301025
# -------------------------------------------------
#
#
# --------------- Starting trial: 86 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 646us/step - loss: 8.8630e-05 - mean_squared_error: 8.8630e-05
# Loss: 8.862969116307795e-05 , Elapsed time: 283.09273648262024
# -------------------------------------------------
#
#
# --------------- Starting trial: 87 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 893us/step - loss: 8.1694e-05 - mean_squared_error: 8.1694e-05
# Loss: 8.169380453182384e-05 , Elapsed time: 296.49146485328674
# -------------------------------------------------
#
#
# --------------- Starting trial: 88 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 705us/step - loss: 7.4364e-05 - mean_squared_error: 7.4364e-05
# Loss: 7.436391024384648e-05 , Elapsed time: 296.52057242393494
# -------------------------------------------------
#
# 4  	16    	2.56285e-05	0.000303524	0.00360034
#
# --------------- Starting trial: 89 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 683us/step - loss: 6.9623e-05 - mean_squared_error: 6.9623e-05
# Loss: 6.962297629797831e-05 , Elapsed time: 293.05516815185547
# -------------------------------------------------
#
#
# --------------- Starting trial: 90 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 813us/step - loss: 1.9044e-04 - mean_squared_error: 1.9044e-04
# Loss: 0.00019043911015614867 , Elapsed time: 157.0355987548828
# -------------------------------------------------
#
#
# --------------- Starting trial: 91 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 697us/step - loss: 4.2419e-05 - mean_squared_error: 4.2419e-05
# Loss: 4.241944770910777e-05 , Elapsed time: 298.892014503479
# -------------------------------------------------
#
#
# --------------- Starting trial: 92 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 728us/step - loss: 1.0622e-04 - mean_squared_error: 1.0622e-04
# Loss: 0.00010621797264320776 , Elapsed time: 293.4365749359131
# -------------------------------------------------
#
#
# --------------- Starting trial: 93 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 708us/step - loss: 5.7312e-04 - mean_squared_error: 5.7312e-04
# Loss: 0.0005731245037168264 , Elapsed time: 153.96658873558044
# -------------------------------------------------
#
#
# --------------- Starting trial: 94 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 704us/step - loss: 8.5669e-05 - mean_squared_error: 8.5669e-05
# Loss: 8.566883479943499e-05 , Elapsed time: 292.40118288993835
# -------------------------------------------------
#
#
# --------------- Starting trial: 95 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 701us/step - loss: 6.3511e-05 - mean_squared_error: 6.3511e-05
# Loss: 6.351072079269215e-05 , Elapsed time: 294.764034986496
# -------------------------------------------------
#
#
# --------------- Starting trial: 96 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 770us/step - loss: 8.8276e-05 - mean_squared_error: 8.8276e-05
# Loss: 8.827556303003803e-05 , Elapsed time: 294.8515167236328
# -------------------------------------------------
#
#
# --------------- Starting trial: 97 ---------------
# Deep layers: 4 , Number of neurons: 100 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 855us/step - loss: 8.8247e-05 - mean_squared_error: 8.8247e-05
# Loss: 8.824658289086074e-05 , Elapsed time: 294.3241539001465
# -------------------------------------------------
#
#
# --------------- Starting trial: 98 ---------------
# Deep layers: 4 , Number of neurons: 50 , Learning rate: 0.0001
# 12/12 [==============================] - 0s 640us/step - loss: 9.0865e-04 - mean_squared_error: 9.0865e-04
# Loss: 0.0009086495265364647 , Elapsed time: 148.4714629650116
# -------------------------------------------------
#
# 5  	10    	2.56285e-05	0.000142836	0.00090865
# -- Best Individual =  [1, 1, 1, 0]
# -- Best Fitness =  2.5628534785937518e-05
# Total elapsed time: 418.05025698741275 minutes

# %%
best_deep_layers   = []
best_num_units     = []
best_learning_rate = []
best_batch_size    = []
# best_activation_f  = []
best_f_names       = []

t = 0

for bi in best_population:
    deep_layers_bits   = BitArray(bi[0:1])    # (8)
    num_units_bits     = BitArray(bi[1:2])    # (16)
    learning_rate_bits = BitArray(bi[2:3])   # (8)
    batch_size_bits    = BitArray(bi[3:4])  # (4)
#     activation_f_bits  = BitArray(bi[12:13])  # (2)
    t += 1 
    
    best_deep_layers.append(SC_DEEP[deep_layers_bits.uint])
    best_num_units.append(SC_NUM_UNITS[num_units_bits.uint])
    best_learning_rate.append(SC_LEARNING[learning_rate_bits.uint])
    best_batch_size.append(SC_BATCH[batch_size_bits.uint])
#     best_activation_f.append(SC_ACTIVATION[activation_f_bits.uint])
#     best_f_names.append(f_names[activation_f_bits.uint])
    
    print('k=',t,'\nDeep layers:', best_deep_layers[-1])
    print('Number of neurons:', best_num_units[-1], ', Batch size', best_batch_size[-1], ', Learning rate:', best_learning_rate[-1])
# Out:
# k= 1
# Deep layers: 4
# Number of neurons: 100 , Batch size 4 , Learning rate: 0.0001

# %%
filename = "historial_genetic_ecsdiff.txt"
df = pd.DataFrame(datos, columns = ["Deep layers", "Num units", "Learning rate", "Batch size", "Loss", "Score", "Elapsed time"])

df.sort_values(by=["Loss", "Elapsed time"], ascending=[True, True], ignore_index=True, inplace=True)

df.to_csv(filename, header=True, index=False, sep='\t', mode='w') # a=append, w=overwrite
df.head(50)
# Out:
#     Deep layers  Num units  Learning rate  Batch size      Loss     Score  \
# 0             4        100         0.0001           4  0.000026  0.000026
# 1             4         50         0.0001           4  0.000035  0.000035
# 2             4        100         0.0001           4  0.000036  0.000036
# 3             4        100         0.0001           4  0.000037  0.000037
# 4             4        100         0.0001           4  0.000041  0.000041
# 5             4        100         0.0001           4  0.000042  0.000042
# 6             4        100         0.0001           4  0.000044  0.000044
# 7             4        100         0.0001           4  0.000059  0.000059
# 8             4        100         0.0001           4  0.000061  0.000061
# 9             4        100         0.0001           4  0.000062  0.000062
# 10            4        100         0.0001           4  0.000063  0.000063
# 11            4        100         0.0001           4  0.000064  0.000064
# 12            4        100         0.0001           4  0.000064  0.000064
# 13            4        100         0.0001           4  0.000070  0.000070
# 14            4        100         0.0001           4  0.000071  0.000071
# 15            4        100         0.0001           4  0.000074  0.000074
# 16            4        100         0.0001           4  0.000079  0.000079
# 17            4        100         0.0001           4  0.000079  0.000079
# 18            4        100         0.0001           4  0.000080  0.000080
# 19            4        100         0.0001           4  0.000082  0.000082
# 20            4        100         0.0001           4  0.000085  0.000085
# 21            4        100         0.0001           4  0.000086  0.000086
# 22            4        100         0.0001           4  0.000088  0.000088
# 23            4        100         0.0001           4  0.000088  0.000088
# 24            4        100         0.0001           4  0.000089  0.000089
# 25            4        100         0.0001           4  0.000091  0.000091
# 26            4        100         0.0001           4  0.000106  0.000106
# 27            3         50         0.0001           4  0.000111  0.000111
# 28            4         50         0.0001           4  0.000116  0.000116
# 29            4         50         0.0001           4  0.000125  0.000125
# 30            4        100         0.0001           4  0.000134  0.000134
# 31            4        100         0.0001           4  0.000139  0.000139
# 32            4         50         0.0001           4  0.000145  0.000145
# 33            4         50         0.0001           4  0.000173  0.000173
# 34            4         50         0.0001           4  0.000173  0.000173
# 35            4        100         0.0001           8  0.000173  0.000173
# 36            4         50         0.0001           4  0.000174  0.000174
# 37            4         50         0.0001           4  0.000177  0.000177
# 38            4        100         0.0001           4  0.000185  0.000185
# 39            4         50         0.0001           4  0.000185  0.000185
# 40            4        100         0.0001           8  0.000190  0.000190
# 41            3         50         0.0001           4  0.000197  0.000197
# 42            4         50         0.0001           4  0.000208  0.000208
# 43            4         50         0.0001           4  0.000208  0.000208
# 44            4         50         0.0001           4  0.000210  0.000210
# 45            4         50         0.0001           4  0.000215  0.000215
# 46            4         50         0.0001           4  0.000232  0.000232
# 47            4         50         0.0001           4  0.000233  0.000233
# 48            3        100         0.0001           4  0.000234  0.000234
# 49            4         50         0.0001           4  0.000242  0.000242
#
#     Elapsed time
# 0     279.340699
# 1     280.995752
# 2     312.675931
# 3     279.863279
# 4     278.680788
# 5     298.892015
# 6     279.505148
# 7     280.696389
# 8     280.801228
# 9     307.092518
# 10    279.363060
# 11    294.764035
# 12    278.518582
# 13    293.055168
# 14    278.965641
# 15    296.520572
# 16    279.255117
# 17    281.021688
# 18    279.111091
# 19    296.491465
# 20    306.569425
# 21    292.401183
# 22    294.324154
# 23    294.851517
# 24    283.092736
# 25    278.887027
# 26    293.436575
# 27    283.375088
# 28    282.268014
# 29    281.897050
# 30    280.296128
# 31    281.417561
# 32    282.606149
# 33    292.606877
# 34    291.225825
# 35    145.861207
# 36    285.009415
# 37    281.894987
# 38    282.794830
# 39    283.369169
# 40    157.035599
# 41    288.527705
# 42    281.424906
# 43    281.705961
# 44    283.616082
# 45    281.175960
# 46    284.453982
# 47    280.740350
# 48    269.244874
# 49    284.983443

# %%
total_time = float(np.sum(df[["Elapsed time"]])/60)

print("Elapsed time {:.3f} minutes".format(total_time))
# Out:
# Elapsed time 418.047 minutes
